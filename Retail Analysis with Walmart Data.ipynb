# %%
# !pip install panda
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting panda
#   Downloading panda-0.3.1.tar.gz (5.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: setuptools in c:\program files\python310\lib\site-packages (from panda) (58.1.0)
# Requirement already satisfied: requests in c:\users\asus\appdata\roaming\python\python310\site-packages (from panda) (2.28.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asus\appdata\roaming\python\python310\site-packages (from requests->panda) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\appdata\roaming\python\python310\site-packages (from requests->panda) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\appdata\roaming\python\python310\site-packages (from requests->panda) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\appdata\roaming\python\python310\site-packages (from requests->panda) (3.4)
# Building wheels for collected packages: panda
#   Building wheel for panda (setup.py): started
#   Building wheel for panda (setup.py): finished with status 'done'
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7263 sha256=8f82e34bf816e181c01e7730590306e9a7967afdc088775acbcf2489ff7a73ad
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\0e\8b\c3\ff9cbde1fffd8071cff8367a86f0350a1ce30a8d31b6a432e9
# Successfully built panda
# Installing collected packages: panda
# Successfully installed panda-0.3.1
# [notice] A new release of pip available: 22.2.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\asus\appdata\roaming\python\python310\site-packages (0.12.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\asus\appdata\roaming\python\python310\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\asus\appdata\roaming\python\python310\site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\asus\appdata\roaming\python\python310\site-packages (from seaborn) (3.7.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\asus\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\roaming\python\python310\site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# [notice] A new release of pip available: 22.2.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib import dates
# %matplotlib inline

# %%
import seaborn as sns

# %%
import datetime as dt

# %%
import warnings

# %%
dataframe = pd.read_csv(r"C:\Users\ASUS\OneDrive\Desktop\test jupyter\Walmart_Store_sales.csv")

# %%
dataframe
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
dataframe.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
dataframe.columns = dataframe.columns.str.lower()
dataframe.columns
# Out:
# Index(['store', 'date', 'weekly_sales', 'holiday_flag', 'temperature',
#        'fuel_price', 'cpi', 'unemployment'],
#       dtype='object')

# %%
dataframe.isnull().sum()
# Out:
# store           0
# date            0
# weekly_sales    0
# holiday_flag    0
# temperature     0
# fuel_price      0
# cpi             0
# unemployment    0
# dtype: int64

# %%
# WHICH STORE HAS MAXIMUM SALES

store_weekly_sales = dataframe.groupby('store')['weekly_sales'].sum()
store_weekly_sales.to_frame()
# Out:
#        weekly_sales
# store
# 1      2.224028e+08
# 2      2.753824e+08
# 3      5.758674e+07
# 4      2.995440e+08
# 5      4.547569e+07
# 6      2.237561e+08
# 7      8.159828e+07
# 8      1.299512e+08
# 9      7.778922e+07
# 10     2.716177e+08
# 11     1.939628e+08
# 12     1.442872e+08
# 13     2.865177e+08
# 14     2.889999e+08
# 15     8.913368e+07
# 16     7.425243e+07
# 17     1.277821e+08
# 18     1.551147e+08
# 19     2.066349e+08
# 20     3.013978e+08
# 21     1.081179e+08
# 22     1.470756e+08
# 23     1.987506e+08
# 24     1.940160e+08
# 25     1.010612e+08
# 26     1.434164e+08
# 27     2.538559e+08
# 28     1.892637e+08
# 29     7.714155e+07
# 30     6.271689e+07
# 31     1.996139e+08
# 32     1.668192e+08
# 33     3.716022e+07
# 34     1.382498e+08
# 35     1.315207e+08
# 36     5.341221e+07
# 37     7.420274e+07
# 38     5.515963e+07
# 39     2.074455e+08
# 40     1.378703e+08
# 41     1.813419e+08
# 42     7.956575e+07
# 43     9.056544e+07
# 44     4.329309e+07
# 45     1.123953e+08

# %%
#using argmax to get the max sales store data

print('Store With Greatest Weekly Sales: ',store_weekly_sales.index[store_weekly_sales.argmax()])
print('Total Sales: ',"{:.2f}".format(store_weekly_sales.max()))
# Out:
# Store With Greatest Weekly Sales:  20
# Total Sales:  301397792.46

# %%
#        WHICH STORE HAS MAXIMUM STANDARD DEVIATION I.E., THE SALES VARY A LOT. 
#        ALSO, FIND OUT THE COEFFICIENT OF MEAN TO STANDARD DEVIATION

store_sales_std = dataframe.groupby('store')['weekly_sales'].std()
store_sales_std.to_frame()
# Out:
#         weekly_sales
# store
# 1      155980.767761
# 2      237683.694682
# 3       46319.631557
# 4      266201.442297
# 5       37737.965745
# 6      212525.855862
# 7      112585.469220
# 8      106280.829881
# 9       69028.666585
# 10     302262.062504
# 11     165833.887863
# 12     139166.871880
# 13     265506.995776
# 14     317569.949476
# 15     120538.652043
# 16      85769.680133
# 17     112162.936087
# 18     176641.510839
# 19     191722.638730
# 20     275900.562742
# 21     128752.812853
# 22     161251.350631
# 23     249788.038068
# 24     167745.677567
# 25     112976.788600
# 26     110431.288141
# 27     239930.135688
# 28     181758.967539
# 29      99120.136596
# 30      22809.665590
# 31     125855.942933
# 32     138017.252087
# 33      24132.927322
# 34     104630.164676
# 35     211243.457791
# 36      60725.173579
# 37      21837.461190
# 38      42768.169450
# 39     217466.454833
# 40     119002.112858
# 41     187907.162766
# 42      50262.925530
# 43      40598.413260
# 44      24762.832015
# 45     130168.526635

# %%
#using argmax to get the max std.dev store data

print('Store With Maximum Standard Deviation: ',store_sales_std.index[store_sales_std.argmax()])
print('STD: ',"{:.2f}".format(store_sales_std.max()))
# Out:
# Store With Maximum Standard Deviation:  14
# STD:  317569.95

# %%
#COVARIANCE

store_sales_mean = dataframe.groupby('store')['weekly_sales'].mean()
store_sales_mean.to_frame()
# Out:
#        weekly_sales
# store
# 1      1.555264e+06
# 2      1.925751e+06
# 3      4.027044e+05
# 4      2.094713e+06
# 5      3.180118e+05
# 6      1.564728e+06
# 7      5.706173e+05
# 8      9.087495e+05
# 9      5.439806e+05
# 10     1.899425e+06
# 11     1.356383e+06
# 12     1.009002e+06
# 13     2.003620e+06
# 14     2.020978e+06
# 15     6.233125e+05
# 16     5.192477e+05
# 17     8.935814e+05
# 18     1.084718e+06
# 19     1.444999e+06
# 20     2.107677e+06
# 21     7.560691e+05
# 22     1.028501e+06
# 23     1.389864e+06
# 24     1.356755e+06
# 25     7.067215e+05
# 26     1.002912e+06
# 27     1.775216e+06
# 28     1.323522e+06
# 29     5.394514e+05
# 30     4.385796e+05
# 31     1.395901e+06
# 32     1.166568e+06
# 33     2.598617e+05
# 34     9.667816e+05
# 35     9.197250e+05
# 36     3.735120e+05
# 37     5.189003e+05
# 38     3.857317e+05
# 39     1.450668e+06
# 40     9.641280e+05
# 41     1.268125e+06
# 42     5.564039e+05
# 43     6.333247e+05
# 44     3.027489e+05
# 45     7.859814e+05

# %%
#cv = (mean / std.dev) * 100

covariance_std_mean = ((store_sales_std/store_sales_mean)*100)

covariance_std_mean.to_frame()
# Out:
#        weekly_sales
# store
# 1         10.029212
# 2         12.342388
# 3         11.502141
# 4         12.708254
# 5         11.866844
# 6         13.582286
# 7         19.730469
# 8         11.695283
# 9         12.689547
# 10        15.913349
# 11        12.226183
# 12        13.792532
# 13        13.251363
# 14        15.713674
# 15        19.338399
# 16        16.518065
# 17        12.552067
# 18        16.284550
# 19        13.268012
# 20        13.090269
# 21        17.029239
# 22        15.678288
# 23        17.972115
# 24        12.363738
# 25        15.986040
# 26        11.011066
# 27        13.515544
# 28        13.732974
# 29        18.374247
# 30         5.200804
# 31         9.016105
# 32        11.831049
# 33         9.286835
# 34        10.822524
# 35        22.968111
# 36        16.257891
# 37         4.208412
# 38        11.087545
# 39        14.990779
# 40        12.342978
# 41        14.817711
# 42         9.033533
# 43         6.410363
# 44         8.179331
# 45        16.561273

# %%
#covariance values (Cv) less than 10 are very good and Cv greater than 30 are not acceptable
#stores 30,31,33,37,42,43,44

# %%
dataframe.head
# Out:
# <bound method NDFrame.head of       store        date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              cpi  unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]>

# %%
dataframe
# Out:
#       store        date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              cpi  unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
#  WHICH STORE/S HAS GOOD QUARTERLY GROWTH RATE IN Q3’2012

#converting date column from object dtype to datetime dtype

dataframe['date'] = dataframe['date'].apply(lambda x:dt.datetime.strptime(x,"%d-%m-%Y"))

# %%
#using datetimeindex to get year/month/day from dataset

dataframe['year'] = pd.DatetimeIndex(dataframe['date']).year
dataframe['month'] = pd.DatetimeIndex(dataframe['date']).month
dataframe['day'] = pd.DatetimeIndex(dataframe['date']).day

dataframe.head()
# Out:
#    store       date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
#
#           cpi  unemployment  year  month  day
# 0  211.096358         8.106  2010      2    5
# 1  211.242170         8.106  2010      2   12
# 2  211.289143         8.106  2010      2   19
# 3  211.319643         8.106  2010      2   26
# 4  211.350143         8.106  2010      3    5

# %%
#converting date back to string with our desired format

dataframe['date'] = dataframe['date'].apply(lambda x:dt.datetime.strftime(x,"%d-%b-%y"))

# %%
month_dict = {1:"Jan", 2:"Feb", 3:"Mar", 4:"Apr", 5:"May", 6:"Jun", 7:"Jul", 8:"Aug", 9:"Sep", 10:"Oct", 11:"Nov",12:"Dec"}

#converting month int values to corresponding month names using apply function and dictionary

dataframe['month'] = dataframe['month'].apply(lambda x: month_dict[x])

dataframe.head()
# Out:
#    store       date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 0      1  05-Feb-10    1643690.90             0        42.31       2.572
# 1      1  12-Feb-10    1641957.44             1        38.51       2.548
# 2      1  19-Feb-10    1611968.17             0        39.93       2.514
# 3      1  26-Feb-10    1409727.59             0        46.63       2.561
# 4      1  05-Mar-10    1554806.68             0        46.50       2.625
#
#           cpi  unemployment  year month  day
# 0  211.096358         8.106  2010   Feb    5
# 1  211.242170         8.106  2010   Feb   12
# 2  211.289143         8.106  2010   Feb   19
# 3  211.319643         8.106  2010   Feb   26
# 4  211.350143         8.106  2010   Mar    5

# %%
#group the data by years

yearly_walmart_data = dataframe.groupby('year')
yearly_walmart_data.ngroups
# Out:
# 3

# %%
#getting groups of the different years

stores_sales_2010 = yearly_walmart_data.get_group(2010)
stores_sales_2011 = yearly_walmart_data.get_group(2011)
stores_sales_2012 = yearly_walmart_data.get_group(2012)
stores_sales_2012.head()
# Out:
#      store       date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 100      1  06-Jan-12    1550369.92             0        49.01       3.157
# 101      1  13-Jan-12    1459601.17             0        48.53       3.261
# 102      1  20-Jan-12    1394393.84             0        54.11       3.268
# 103      1  27-Jan-12    1319325.59             0        54.26       3.290
# 104      1  03-Feb-12    1636339.65             0        56.55       3.360
#
#             cpi  unemployment  year month  day
# 100  219.714258         7.348  2012   Jan    6
# 101  219.892526         7.348  2012   Jan   13
# 102  219.985689         7.348  2012   Jan   20
# 103  220.078852         7.348  2012   Jan   27
# 104  220.172015         7.348  2012   Feb    3

# %%
#adding a new column to find and store quartile values

stores_sales_2012['quarter'] = 0

stores_sales_2012.head()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\675434618.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'] = 0
#      store       date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 100      1  06-Jan-12    1550369.92             0        49.01       3.157
# 101      1  13-Jan-12    1459601.17             0        48.53       3.261
# 102      1  20-Jan-12    1394393.84             0        54.11       3.268
# 103      1  27-Jan-12    1319325.59             0        54.26       3.290
# 104      1  03-Feb-12    1636339.65             0        56.55       3.360
#
#             cpi  unemployment  year month  day  quarter
# 100  219.714258         7.348  2012   Jan    6        0
# 101  219.892526         7.348  2012   Jan   13        0
# 102  219.985689         7.348  2012   Jan   20        0
# 103  220.078852         7.348  2012   Jan   27        0
# 104  220.172015         7.348  2012   Feb    3        0

# %%
#if elif loop to split months into quartiles

for i in stores_sales_2012['month']:
    if i in ['Jan', 'Feb', 'Mar']:
        stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
    elif i in ['Apr', 'May', 'Jun']:
        stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
    elif i in ['Jul', 'Aug', 'Sep']:
        stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
    elif i in ['Oct', 'Nov', 'Dec']:
        stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q4"       
        
stores_sales_2012
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q4"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q4"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q4"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q4"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q4"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q4"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q4"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q4"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q4"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q4"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# ...
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q1"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q2"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q3"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q4"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q4"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q4"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q4"
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3440882593.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_sales_2012['quarter'][stores_sales_2012[stores_sales_2012['month'] == i].index] = "Q4"
#       store       date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 100       1  06-Jan-12    1550369.92             0        49.01       3.157
# 101       1  13-Jan-12    1459601.17             0        48.53       3.261
# 102       1  20-Jan-12    1394393.84             0        54.11       3.268
# 103       1  27-Jan-12    1319325.59             0        54.26       3.290
# 104       1  03-Feb-12    1636339.65             0        56.55       3.360
# ...     ...        ...           ...           ...          ...         ...
# 6430     45  28-Sep-12     713173.95             0        64.88       3.997
# 6431     45  05-Oct-12     733455.07             0        64.89       3.985
# 6432     45  12-Oct-12     734464.36             0        54.47       4.000
# 6433     45  19-Oct-12     718125.53             0        56.47       3.969
# 6434     45  26-Oct-12     760281.43             0        58.85       3.882
#
#              cpi  unemployment  year month  day quarter
# 100   219.714258         7.348  2012   Jan    6      Q1
# 101   219.892526         7.348  2012   Jan   13      Q1
# 102   219.985689         7.348  2012   Jan   20      Q1
# 103   220.078852         7.348  2012   Jan   27      Q1
# 104   220.172015         7.348  2012   Feb    3      Q1
# ...          ...           ...   ...   ...  ...     ...
# 6430  192.013558         8.684  2012   Sep   28      Q3
# 6431  192.170412         8.667  2012   Oct    5      Q4
# 6432  192.327265         8.667  2012   Oct   12      Q4
# 6433  192.330854         8.667  2012   Oct   19      Q4
# 6434  192.308899         8.667  2012   Oct   26      Q4
#
# [1935 rows x 12 columns]

# %%
#group data by quartiles

quartiles_sales_2012 = stores_sales_2012.groupby('quarter')
quartiles_sales_2012.ngroups
# Out:
# 4

# %%
#get individual quartile groups(Q1, Q2, Q3, Q4)

q1_data = quartiles_sales_2012.get_group('Q1')
q2_data = quartiles_sales_2012.get_group('Q2')
q3_data = quartiles_sales_2012.get_group('Q3')
q4_data = quartiles_sales_2012.get_group('Q4')

# %%
#get total sales of all stores in each quarter

q1_sales = q1_data.groupby('store')['weekly_sales'].sum()
q2_sales = q2_data.groupby('store')['weekly_sales'].sum()
q3_sales = q3_data.groupby('store')['weekly_sales'].sum()
q4_sales = q4_data.groupby('store')['weekly_sales'].sum()

sorted_q2_sales = q2_sales.sort_values(ascending=False)
sorted_q2_sales.head(10)
# Out:
# store
# 4     28454363.67
# 20    27524197.32
# 13    27009207.14
# 14    25155535.41
# 2     25083604.88
# 10    23750369.17
# 27    22744012.75
# 1     20978760.12
# 6     20833909.92
# 39    20214128.46
# Name: weekly_sales, dtype: float64

# %%
sorted_q3_sales = q3_sales.sort_values(ascending=False)
sorted_q3_sales.head(10)
# Out:
# store
# 4     27796792.46
# 20    26891526.98
# 13    26421259.30
# 2     24303354.86
# 10    23037258.76
# 27    22307711.41
# 14    21187560.65
# 39    20715116.23
# 1     20253947.78
# 6     20167312.24
# Name: weekly_sales, dtype: float64

# %%
#finding the Q3 growth rate for each store

q3_salesgrowth = q3_sales - q2_sales
q3_salesgrowth.to_frame()
# Out:
#        weekly_sales
# store
# 1        -724812.34
# 2        -780250.02
# 3        -322311.02
# 4        -657571.21
# 5        -302572.70
# 6        -666597.68
# 7         971928.12
# 8        -170678.25
# 9        -462785.55
# 10       -713110.41
# 11       -271290.51
# 12       -826064.21
# 13       -587947.84
# 14      -3967974.76
# 15       -343162.04
# 16        557205.66
# 17       -132947.88
# 18       -406429.38
# 19       -163745.39
# 20       -632670.34
# 21       -266997.03
# 22       -642754.35
# 23        152606.33
# 24        292158.81
# 25       -213930.25
# 26        520356.34
# 27       -436301.34
# 28       -426188.16
# 29       -454073.36
# 30       -147612.43
# 31       -460524.05
# 32        -92742.10
# 33       -115380.03
# 34       -367622.08
# 35        484108.12
# 36       -320299.94
# 37        -96481.13
# 38        -32436.44
# 39        500987.77
# 40        145457.84
# 41        433901.28
# 42       -271479.93
# 43       -168264.19
# 44        104845.38
# 45       -809499.45

# %%
#using argmax to find the store that has maximum sales growth in quarter 3

print('Store With Maximum Sales Growth: ',q3_salesgrowth.index[q3_salesgrowth.argmax()])
print('Sales Growth: ',"{:.2f}".format(q3_salesgrowth.max()))
# Out:
# Store With Maximum Sales Growth:  7
# Sales Growth:  971928.12

# %%
#        SOME HOLIDAYS HAVE A NEGATIVE IMPACT ON SALES. FIND OUT HOLIDAYS WHICH HAVE HIGHER SALES THAN THE MEAN SALES IN 
#        NON-HOLIDAY SEASON FOR ALL STORES TOGETHER

#        Super Bowl: 12-Feb-10, 11-Feb-11, 10-Feb-12
#        Labour Day: 10-Sep-10, 9-Sep-11, 7-Sep-12
#        Thanksgiving: 26-Nov-10, 25-Nov-11
#        Christmas: 31-Dec-10, 30-Dec-11

# %%
superbowl_sales = dataframe[(dataframe['date'] == '12-Feb-10')|(dataframe['date'] == '11-Feb-11')|(dataframe['date'] == '10-Feb-12')]
print('Mean Superbowl Sales: ',"{:.2f}".format(superbowl_sales['weekly_sales'].mean()))

labourday_sales = dataframe[(dataframe['date'] == '10-Sep-10')|(dataframe['date'] == '09-Sep-11')|(dataframe['date'] == '07-Sep-12')]
print('Mean Labour Day Sales: ',"{:.2f}".format(labourday_sales['weekly_sales'].mean()))

thanksgiving_sales = dataframe[(dataframe['date'] == '26-Nov-10')|(dataframe['date'] == '25-Nov-11')]
print('Mean Thanksgiving Sales: ',"{:.2f}".format(thanksgiving_sales['weekly_sales'].mean()))

christmas_sales = dataframe[(dataframe['date'] == '31-Dec-10')|(dataframe['date'] == '30-Dec-11')]
print('Mean Christmas Sales: ',"{:.2f}".format(christmas_sales['weekly_sales'].mean()))
# Out:
# Mean Superbowl Sales:  1079127.99
# Mean Labour Day Sales:  1042427.29
# Mean Thanksgiving Sales:  1471273.43
# Mean Christmas Sales:  960833.11

# %%
def plot_line(df,holiday_dates,holiday_label):
    fig, ax = plt.subplots(figsize = (15,5))  
    ax.plot(df['date'],df['weekly_sales'],label=holiday_label)
    
    for day in holiday_dates:
        day = dt.datetime.strptime(day, '%d-%m-%Y')
        plt.axvline(x=day, linestyle='--', c='r')
    

    plt.title(holiday_label)
    x_dates = df['date'].dt.strftime('%Y-%m-%d').sort_values().unique()
    xfmt = dates.DateFormatter('%d-%m-%Y')
    ax.xaxis.set_major_formatter(xfmt)
    ax.xaxis.set_major_locator(dates.DayLocator(1))
    plt.gcf().autofmt_xdate(rotation=90)
    plt.show()


total_sales = dataframe.groupby('date')['weekly_sales'].sum().reset_index()

Super_Bowl =['12-2-2010', '11-2-2011', '10-2-2012']
Labour_Day =  ['10-9-2010', '9-9-2011', '7-9-2012']
Thanksgiving =  ['26-11-2010', '25-11-2011', '23-11-2012']
Christmas = ['31-12-2010', '30-12-2011', '28-12-2012']
    
plot_line(total_sales,Super_Bowl,'Super Bowl')
plot_line(total_sales,Labour_Day,'Labour Day')
plot_line(total_sales,Thanksgiving,'Thanksgiving')
plot_line(total_sales,Christmas,'Christmas')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\axis.py:1736, in Axis.convert_units(self, x)
#    1735 try:
# -> 1736     ret = self.converter.convert(x, self.units, self)
#    1737 except Exception as e:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\category.py:57, in StrCategoryConverter.convert(value, unit, axis)
#      56 # force an update so it also does type checking
# ---> 57 unit.update(values)
#      58 return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\category.py:216, in UnitData.update(self, data)
#     214 for val in OrderedDict.fromkeys(data):
#     215     # OrderedDict just iterates over unique values in data.
# --> 216     _api.check_isinstance((str, bytes), value=val)
#     217     if convertible:
#     218         # this will only be called so long as convertible is True.
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\_api\__init__.py:93, in check_isinstance(_types, **kwargs)
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a datetime.datetime
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Input In [48], in <cell line: 26>()
#      23 Thanksgiving =  ['26-11-2010', '25-11-2011', '23-11-2012']
#      24 Christmas = ['31-12-2010', '30-12-2011', '28-12-2012']
# ---> 26 plot_line(total_sales,Super_Bowl,'Super Bowl')
#      27 plot_line(total_sales,Labour_Day,'Labour Day')
#      28 plot_line(total_sales,Thanksgiving,'Thanksgiving')
#
# Input In [48], in plot_line(df, holiday_dates, holiday_label)
#       5 for day in holiday_dates:
#       6     day = dt.datetime.strptime(day, '%d-%m-%Y')
# ----> 7     plt.axvline(x=day, linestyle='--', c='r')
#      10 plt.title(holiday_label)
#      11 x_dates = df['date'].dt.strftime('%Y-%m-%d').sort_values().unique()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\pyplot.py:2398, in axvline(x, ymin, ymax, **kwargs)
#    2396 @_copy_docstring_and_deprecators(Axes.axvline)
#    2397 def axvline(x=0, ymin=0, ymax=1, **kwargs):
# -> 2398     return gca().axvline(x=x, ymin=ymin, ymax=ymax, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\axes\_axes.py:836, in Axes.axvline(self, x, ymin, ymax, **kwargs)
#     833 xmin, xmax = self.get_xbound()
#     835 # Strip away the units for comparison with non-unitized bounds.
# --> 836 xx, = self._process_unit_info([("x", x)], kwargs)
#     837 scalex = (xx < xmin) or (xx > xmax)
#     839 trans = self.get_xaxis_transform(which='grid')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\axes\_base.py:2569, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2567             if dataset_axis_name == axis_name and data is not None:
#    2568                 axis.update_units(data)
# -> 2569 return [axis_map[axis_name].convert_units(data)
#    2570         if convert and data is not None else data
#    2571         for axis_name, data in datasets]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\axes\_base.py:2569, in <listcomp>(.0)
#    2567             if dataset_axis_name == axis_name and data is not None:
#    2568                 axis.update_units(data)
# -> 2569 return [axis_map[axis_name].convert_units(data)
#    2570         if convert and data is not None else data
#    2571         for axis_name, data in datasets]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\axis.py:1738, in Axis.convert_units(self, x)
#    1736     ret = self.converter.convert(x, self.units, self)
#    1737 except Exception as e:
# -> 1738     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1739                                  f'units: {x!r}') from e
#    1740 return ret
#
# ConversionError: Failed to convert value(s) to axis units: datetime.datetime(2010, 2, 12, 0, 0)

# %%
#grouping dataset by holiday flag

holidays_df = dataframe.groupby('holiday_flag')

# %%
#getting only holiday data

holiday_sales = holidays_df.get_group(1)
print('Mean Holiday Sales: ',"{:.2f}".format(holiday_sales['weekly_sales'].mean()))
# Out:
# Mean Holiday Sales:  1122887.89

# %%
#getting only non-holiday data

non_holiday_sales = holidays_df.get_group(0)
print('Mean Non-Holiday Sales: ',"{:.2f}".format(non_holiday_sales['weekly_sales'].mean()))
# Out:
# Mean Non-Holiday Sales:  1041256.38

# %%
#holiday and non-holiday mean sales

print('Mean Superbowl Sales: ',"{:.2f}".format(superbowl_sales['weekly_sales'].mean()))
print('Mean Labour Day Sales: ',"{:.2f}".format(labourday_sales['weekly_sales'].mean()))
print('Mean Thanksgiving Sales: ',"{:.2f}".format(thanksgiving_sales['weekly_sales'].mean()))
print('Mean Christmas Sales: ',"{:.2f}".format(christmas_sales['weekly_sales'].mean()))
print()
print('Mean Non-Holiday Sales: ',"{:.2f}".format(non_holiday_sales['weekly_sales'].mean()))
# Out:
# Mean Superbowl Sales:  1079127.99
# Mean Labour Day Sales:  1042427.29
# Mean Thanksgiving Sales:  1471273.43
# Mean Christmas Sales:  960833.11
#
# Mean Non-Holiday Sales:  1041256.38

# %%
#Superbowl, Labour Day and Thanksgiving all have position sales impacts while Christmas has a negative impact

# %%
#     PROVIDE A MONTHLY VIEW OF SALES IN UNITS AND GIVE INSIGHTS

total_monthly_sales = dataframe.groupby('month')
total_monthly_sales.ngroups
# Out:
# 12

# %%
total_monthly_sales['weekly_sales'].describe()
# Out:
#        count          mean            std        min          25%  \
# month
# Apr    630.0  1.026762e+06  543864.624192  232769.09  534583.5075
# Aug    585.0  1.048017e+06  542653.059046  224031.19  575997.7800
# Dec    450.0  1.281864e+06  774037.720767  209986.25  616295.8450
# Feb    540.0  1.053200e+06  564207.057354  234218.03  554628.6350
# Jan    360.0  9.238846e+05  472616.460339  231155.90  521051.0125
# Jul    630.0  1.031748e+06  531141.778886  224806.96  577830.8550
# Jun    585.0  1.064325e+06  548683.953608  238172.66  581745.7200
# Mar    585.0  1.013309e+06  529805.743801  238084.08  544408.1400
# May    540.0  1.031714e+06  536589.412470  239206.26  543588.2225
# Nov    360.0  1.147266e+06  648832.347036  224639.76  585869.0500
# Oct    585.0  9.996321e+05  517186.653614  213538.32  534738.4300
# Sep    585.0  9.893353e+05  510532.949375  229731.98  533161.6400
#
#                50%          75%         max
# month
# Apr     948789.575  1402726.700  2565259.92
# Aug     969387.480  1442819.280  2283540.30
# Dec    1154880.920  1714442.515  3818686.45
# Feb     980765.180  1431376.635  2623469.95
# Jan     830944.935  1256202.130  2047766.07
# Jul     953770.830  1396269.865  2358055.30
# Jun     984336.040  1442092.080  2363601.47
# Mar     943951.670  1365824.970  2237544.75
# May     969562.080  1388603.735  2370116.52
# Nov    1044710.505  1542527.595  3004702.33
# Oct     937956.890  1363365.050  2246411.89
# Sep     922440.640  1345167.610  2202742.90

# %%
#grouping by month in 2010

monthly_sales_2010 = stores_sales_2010.groupby('month')
monthly_sales_2010['weekly_sales'].describe()
# Out:
#        count          mean            std        min          25%  \
# month
# Apr    225.0  1.028499e+06  545424.247706  257361.30  527019.7800
# Aug    180.0  1.042445e+06  539322.149800  224031.19  573235.4675
# Dec    225.0  1.283380e+06  793498.247838  209986.25  599730.0700
# Feb    180.0  1.057405e+06  571029.268079  267956.30  534468.2225
# Jul    225.0  1.033689e+06  534340.296029  242047.03  570231.2100
# Jun    180.0  1.068034e+06  556849.016817  259419.91  551924.8925
# Mar    180.0  1.010666e+06  531192.529079  262893.76  519202.3825
# May    180.0  1.037283e+06  542985.021379  267065.35  530713.0675
# Nov    180.0  1.126963e+06  642755.592239  224639.76  558963.6550
# Oct    225.0  9.651637e+05  496358.362753  213538.32  514485.9000
# Sep    180.0  9.848216e+05  508207.747513  231976.84  530738.3025
#
#                50%           75%         max
# month
# Apr     969594.470  1.391256e+06  2495630.51
# Aug     981237.730  1.418366e+06  2219813.50
# Dec    1149612.040  1.707298e+06  3818686.45
# Feb     997074.975  1.470286e+06  2623469.95
# Jul     959229.090  1.371987e+06  2334788.42
# Jun    1002244.665  1.423940e+06  2363601.47
# Mar     964763.590  1.340757e+06  2237544.75
# May     973124.460  1.368593e+06  2370116.52
# Nov     995672.600  1.508792e+06  2939946.38
# Oct     891152.330  1.286599e+06  2091663.20
# Sep     910702.500  1.304980e+06  2191767.76

# %%
#grouping by month in 2011

monthly_sales_2011 = stores_sales_2011.groupby('month')
monthly_sales_2011['weekly_sales'].describe()
# Out:
#        count          mean            std        min          25%  \
# month
# Apr    225.0  1.006784e+06  532258.833292  232769.09  534578.7800
# Aug    180.0  1.047774e+06  549887.085283  237095.82  570423.6150
# Dec    225.0  1.280347e+06  755843.504954  215359.21  630327.2800
# Feb    180.0  1.035174e+06  552442.387986  234218.03  556183.5800
# Jan    180.0  9.094665e+05  466122.257495  231155.90  513597.3125
# Jul    225.0  1.021828e+06  526841.700020  224806.96  582381.9500
# Jun    180.0  1.054297e+06  543819.984741  238172.66  585639.7750
# Mar    180.0  9.964247e+05  522341.244321  238084.08  536784.3775
# May    180.0  1.009156e+06  523438.331445  239206.26  543719.8250
# Nov    180.0  1.167569e+06  656014.430247  236157.12  597808.1050
# Oct    180.0  1.018118e+06  533282.121588  231319.96  537294.8075
# Sep    225.0  9.815455e+05  511836.769295  229731.98  537124.7600
#
#                50%           75%         max
# month
# Apr     937473.130  1.372485e+06  2313861.81
# Aug     955710.315  1.445838e+06  2273470.62
# Dec    1158708.980  1.781529e+06  3676388.98
# Feb     961012.950  1.420064e+06  2351143.07
# Jan     812167.545  1.215770e+06  1886393.94
# Jul     936001.980  1.396927e+06  2123787.79
# Jun     974263.155  1.441112e+06  2182246.69
# Mar     929977.755  1.352847e+06  2143424.61
# May     943238.085  1.371667e+06  2095599.93
# Nov    1061735.140  1.559386e+06  3004702.33
# Oct     943328.485  1.406234e+06  2207742.13
# Sep     899834.750  1.347608e+06  2202742.90

# %%
#grouping by month in 2012

monthly_sales_2012 = stores_sales_2012.groupby('month')
monthly_sales_2012['weekly_sales'].describe()
# Out:
#        count          mean            std        min          25%         50%  \
# month
# Apr    180.0  1.049561e+06  558183.253234  249798.75  548516.0000  950743.050
# Aug    225.0  1.052670e+06  541866.268723  237129.81  576620.3100  976137.730
# Feb    180.0  1.067020e+06  571613.468771  242526.70  564122.8100  970644.815
# Jan    180.0  9.383026e+05  479887.956347  236920.49  540523.1525  855680.105
# Jul    180.0  1.041719e+06  535223.017499  249134.32  577204.6500  960529.395
# Jun    225.0  1.069379e+06  548322.510590  244338.31  583648.5900  988764.840
# Mar    225.0  1.028932e+06  536489.204740  246970.97  557547.2500  952264.910
# May    180.0  1.048703e+06  545296.384619  261851.74  549055.7525  988833.255
# Oct    180.0  1.024232e+06  526815.738642  253731.13  548829.2100  962230.855
# Sep    180.0  1.003586e+06  513766.298200  242813.51  532581.7925  949096.910
#
#                 75%         max
# month
# Apr    1.456415e+06  2565259.92
# Aug    1.497055e+06  2283540.30
# Feb    1.448538e+06  2462978.28
# Jan    1.269834e+06  2047766.07
# Jul    1.456741e+06  2358055.30
# Jun    1.451782e+06  2245257.18
# Mar    1.427881e+06  2214967.44
# May    1.428744e+06  2207214.81
# Oct    1.413769e+06  2246411.89
# Sep    1.371256e+06  2165796.31

# %%
plt.figure(figsize=(20,5))
plt.subplots_adjust(hspace=.25)
txt={'weight':'bold'}

plt.subplot(1,3,1)
plt.title('2010 Monthly Sales',fontdict=txt)
monthly_sales_2010['weekly_sales'].sum().plot.bar(color = 'green')
plt.xlabel('Month',fontdict=txt)
plt.ylabel('Weekly Sales',fontdict=txt)

plt.subplot(1,3,2)
plt.title('2011 Monthly Sales',fontdict=txt)
monthly_sales_2011['weekly_sales'].sum().plot.bar(color = 'red')
plt.xlabel('Month',fontdict=txt)
plt.ylabel('Weekly Sales',fontdict=txt)

plt.subplot(1,3,3)
plt.title('2012 Monthly Sales',fontdict=txt)
monthly_sales_2012['weekly_sales'].sum().plot.bar(color = 'blue')
plt.xlabel('Month',fontdict=txt)
plt.ylabel('Weekly Sales',fontdict=txt)

plt.show()

# %%
#    PROVIDE A SEMESTER VIEW OF SALES IN UNITS AND GIVE INSIGHTS

sem_1_2010 = stores_sales_2010[stores_sales_2010['month'].isin(['Jan','Feb','Mar','Apr','May','Jun'])]
sem_1_2010.head()
# Out:
#    store       date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 0      1  05-Feb-10    1643690.90             0        42.31       2.572
# 1      1  12-Feb-10    1641957.44             1        38.51       2.548
# 2      1  19-Feb-10    1611968.17             0        39.93       2.514
# 3      1  26-Feb-10    1409727.59             0        46.63       2.561
# 4      1  05-Mar-10    1554806.68             0        46.50       2.625
#
#           cpi  unemployment  year month  day
# 0  211.096358         8.106  2010   Feb    5
# 1  211.242170         8.106  2010   Feb   12
# 2  211.289143         8.106  2010   Feb   19
# 3  211.319643         8.106  2010   Feb   26
# 4  211.350143         8.106  2010   Mar    5

# %%
sem_2_2010 = stores_sales_2010[stores_sales_2010['month'].isin(['Jul','Aug','Sep','Oct','Nov','Dec'])]
sem_2_2010.head()
# Out:
#     store       date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 21      1  02-Jul-10    1492418.14             0        80.91       2.669
# 22      1  09-Jul-10    1546074.18             0        80.48       2.642
# 23      1  16-Jul-10    1448938.92             0        83.15       2.623
# 24      1  23-Jul-10    1385065.20             0        83.36       2.608
# 25      1  30-Jul-10    1371986.60             0        81.84       2.640
#
#            cpi  unemployment  year month  day
# 21  211.223533         7.787  2010   Jul    2
# 22  211.108414         7.787  2010   Jul    9
# 23  211.100385         7.787  2010   Jul   16
# 24  211.235144         7.787  2010   Jul   23
# 25  211.369903         7.787  2010   Jul   30

# %%
sem_1_2011 = stores_sales_2011[stores_sales_2011['month'].isin(['Jan','Feb','Mar','Apr','May','Jun'])]
sem_1_2011.head()
# Out:
#     store       date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 48      1  07-Jan-11    1444732.28             0        48.27       2.976
# 49      1  14-Jan-11    1391013.96             0        35.40       2.983
# 50      1  21-Jan-11    1327405.42             0        44.04       3.016
# 51      1  28-Jan-11    1316899.31             0        43.83       3.010
# 52      1  04-Feb-11    1606629.58             0        42.27       2.989
#
#            cpi  unemployment  year month  day
# 48  211.404742         7.742  2011   Jan    7
# 49  211.457411         7.742  2011   Jan   14
# 50  211.827234         7.742  2011   Jan   21
# 51  212.197058         7.742  2011   Jan   28
# 52  212.566881         7.742  2011   Feb    4

# %%
    sem_2_2011 = stores_sales_2011[stores_sales_2011['month'].isin(['Jul','Aug','Sep','Oct','Nov','Dec'])]
sem_2_2011.head()
# Out:
#     store       date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 73      1  01-Jul-11    1488538.09             0        85.55       3.524
# 74      1  08-Jul-11    1534849.64             0        85.83       3.480
# 75      1  15-Jul-11    1455119.97             0        88.54       3.575
# 76      1  22-Jul-11    1396926.82             0        85.77       3.651
# 77      1  29-Jul-11    1352219.79             0        86.83       3.682
#
#            cpi  unemployment  year month  day
# 73  215.184137         7.962  2011   Jul    1
# 74  215.277175         7.962  2011   Jul    8
# 75  215.361109         7.962  2011   Jul   15
# 76  215.422278         7.962  2011   Jul   22
# 77  215.483448         7.962  2011   Jul   29

# %%
sem_1_2012 = stores_sales_2012[stores_sales_2012['month'].isin(['Jan','Feb','Mar','Apr','May','Jun'])]
sem_1_2012.head()
# Out:
#      store       date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 100      1  06-Jan-12    1550369.92             0        49.01       3.157
# 101      1  13-Jan-12    1459601.17             0        48.53       3.261
# 102      1  20-Jan-12    1394393.84             0        54.11       3.268
# 103      1  27-Jan-12    1319325.59             0        54.26       3.290
# 104      1  03-Feb-12    1636339.65             0        56.55       3.360
#
#             cpi  unemployment  year month  day quarter
# 100  219.714258         7.348  2012   Jan    6      Q1
# 101  219.892526         7.348  2012   Jan   13      Q1
# 102  219.985689         7.348  2012   Jan   20      Q1
# 103  220.078852         7.348  2012   Jan   27      Q1
# 104  220.172015         7.348  2012   Feb    3      Q1

# %%
sem_2_2012 = stores_sales_2012[stores_sales_2012['month'].isin(['Jul','Aug','Sep','Oct','Nov','Dec'])]
sem_2_2012.head()
# Out:
#      store       date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 126      1  06-Jul-12    1769854.16             0        81.57       3.227
# 127      1  13-Jul-12    1527014.04             0        77.12       3.256
# 128      1  20-Jul-12    1497954.76             0        80.42       3.311
# 129      1  27-Jul-12    1439123.71             0        82.66       3.407
# 130      1  03-Aug-12    1631135.79             0        86.11       3.417
#
#             cpi  unemployment  year month  day quarter
# 126  221.883779         6.908  2012   Jul    6      Q3
# 127  221.924158         6.908  2012   Jul   13      Q3
# 128  221.932727         6.908  2012   Jul   20      Q3
# 129  221.941295         6.908  2012   Jul   27      Q3
# 130  221.949864         6.908  2012   Aug    3      Q3

# %%
stores_sales = [sem_1_2010['weekly_sales'].sum(), sem_1_2011['weekly_sales'].sum(), sem_1_2012['weekly_sales'].sum()]
labels = '2010', '2011', '2012'
cmap = plt.get_cmap('Greens')
colors = cmap(np.arange(3)*95)
txt = {'weight':'bold'}
plt.figure(figsize=(15,5))
plt.title("Sales Percentage")
plt.pie(stores_sales, labels=labels, autopct='%.1f%%', colors=colors, textprops=txt)
plt.show()

# %%
stores_sales = [sem_2_2010['weekly_sales'].sum(), sem_2_2011['weekly_sales'].sum(), sem_2_2012['weekly_sales'].sum()]
labels = '2010', '2011', '2012'
cmap = plt.get_cmap('Greens')
colors = cmap(np.arange(3)*95)
txt = {'weight':'bold'}
plt.figure(figsize=(15,5))
plt.title("Sales Percentage")
plt.pie(stores_sales, labels=labels, autopct='%.1f%%', colors=colors, textprops=txt)
plt.show()

# %%
#2011 had the most sales

# %%
sem_sales_1 = [sem_1_2010['weekly_sales'].sum(), sem_2_2010['weekly_sales'].sum(), 
               sem_1_2011['weekly_sales'].sum(), sem_2_2011['weekly_sales'].sum(),
               sem_1_2012['weekly_sales'].sum(), sem_2_2012['weekly_sales'].sum()]
labels = 'Sem 1 - 2010', 'Sem 2 - 2010', 'Sem 1 - 2011', 'Sem 2 - 2011', 'Sem 1 - 2012', 'Sem 2 - 2012'
cmap = plt.get_cmap('Reds')
colors = cmap(np.arange(2)*150)
txt = {'weight':'bold'}
plt.figure(figsize=(15,5))
plt.title("Semester Sales Percentage")
plt.pie(sem_sales_1, labels=labels, autopct='%.1f%%', colors=colors, textprops=txt)
plt.show()

# %%
#Sales were at their max during the 2nd semeter of 2011

# %%
semester_sales_2010 = [sem_1_2010['weekly_sales'].sum(),sem_2_2010['weekly_sales'].sum()]
semester_sales_2011 = [sem_1_2011['weekly_sales'].sum(),sem_2_2011['weekly_sales'].sum()]
semester_sales_2012 = [sem_1_2012['weekly_sales'].sum(),sem_2_2012['weekly_sales'].sum()]

label = 'Semester 1', 'Semester 2'
cmap = plt.get_cmap('inferno_r')
colors = cmap(np.arange(2)*18)
txt = {'weight':'bold'}
plt.figure(figsize=(20,5))
plt.subplots_adjust(hspace=.25)

plt.subplot(1,3,1)
plt.title("Semester Sales 2010",fontdict=txt)
plt.pie(semester_sales_2010, labels=label, autopct='%.1f%%', colors=colors, textprops=txt)

plt.subplot(1,3,2)
plt.title("Semester Sales 2011",fontdict=txt)
plt.pie(semester_sales_2011, labels=label, autopct='%.1f%%', colors=colors, textprops=txt)

plt.subplot(1,3,3)
plt.title("Semester Sales 2012",fontdict=txt)
plt.pie(semester_sales_2012, labels=label, autopct='%.1f%%', colors=colors, textprops=txt)

plt.show()

# %%
#Semester 2 normally leads in sales except for in 2012

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from statsmodels.formula.api import ols
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [74], in <cell line: 1>()
# ----> 1 from sklearn.model_selection import train_test_split
#       2 from sklearn.linear_model import LinearRegression
#       3 from sklearn import metrics
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip install sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sklearn in c:\users\asus\appdata\roaming\python\python310\site-packages (0.0.post1)
# [notice] A new release of pip available: 22.2.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting statsmodels
#   Downloading statsmodels-0.13.5-cp310-cp310-win_amd64.whl (9.1 MB)
#      ---------------------------------------- 9.1/9.1 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.25 in c:\users\asus\appdata\roaming\python\python310\site-packages (from statsmodels) (1.5.3)
# Requirement already satisfied: scipy>=1.3 in c:\users\asus\appdata\roaming\python\python310\site-packages (from statsmodels) (1.10.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\asus\appdata\roaming\python\python310\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\asus\appdata\roaming\python\python310\site-packages (from statsmodels) (1.24.2)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      -------------------------------------- 233.8/233.8 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\asus\appdata\roaming\python\python310\site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\asus\appdata\roaming\python\python310\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\roaming\python\python310\site-packages (from pandas>=0.25->statsmodels) (2022.7.1)
# Requirement already satisfied: six in c:\users\asus\appdata\roaming\python\python310\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.3 statsmodels-0.13.5
# [notice] A new release of pip available: 22.2.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from statsmodels.formula.api import ols

# %%
# !pip install --user <package>
# Out:
# The syntax of the command is incorrect.

# %%
! pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.1-cp310-cp310-win_amd64.whl (8.3 MB)
#      ---------------------------------------- 8.3/8.3 MB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\users\asus\appdata\roaming\python\python310\site-packages (from scikit-learn) (1.24.2)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      -------------------------------------- 298.0/298.0 kB 1.5 MB/s eta 0:00:00
# Collecting scipy>=1.3.2
#   Downloading scipy-1.10.1-cp310-cp310-win_amd64.whl (42.5 MB)
#      ---------------------------------------- 42.5/42.5 MB 2.9 MB/s eta 0:00:00
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.1 scipy-1.10.1 threadpoolctl-3.1.0
# [notice] A new release of pip available: 22.2.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
from statsmodels.formula.api import ols
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [84], in <cell line: 1>()
# ----> 1 from statsmodels.formula.api import ols
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
#STATISTICAL MODEL FOR STORE 1 – BUILD  PREDICTION MODELS TO FORECAST DEMAND

store_data = dataframe.groupby('store')

store1_dataset = store_data.get_group(1)
store1_dataset['strdate'] = pd.to_datetime(store1_dataset['date'])
store1_dataset['month'] = store1_dataset['strdate'].dt.month
store1_dataset.head()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3219922691.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   store1_dataset['strdate'] = pd.to_datetime(store1_dataset['date'])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\3219922691.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   store1_dataset['month'] = store1_dataset['strdate'].dt.month
#    store       date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 0      1  05-Feb-10    1643690.90             0        42.31       2.572
# 1      1  12-Feb-10    1641957.44             1        38.51       2.548
# 2      1  19-Feb-10    1611968.17             0        39.93       2.514
# 3      1  26-Feb-10    1409727.59             0        46.63       2.561
# 4      1  05-Mar-10    1554806.68             0        46.50       2.625
#
#           cpi  unemployment  year  month  day    strdate
# 0  211.096358         8.106  2010      2    5 2010-02-05
# 1  211.242170         8.106  2010      2   12 2010-02-12
# 2  211.289143         8.106  2010      2   19 2010-02-19
# 3  211.319643         8.106  2010      2   26 2010-02-26
# 4  211.350143         8.106  2010      3    5 2010-03-05

# %%
#restructering dates to numbers to use them in model as categorical data cannot be used in linear mode 1

dummy = []
for i in range (1,144):
    dummy.append(i)

store1_dataset['dummy_date'] = dummy

store1_dataset.head()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53704\992592475.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   store1_dataset['dummy_date'] = dummy
#    store       date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 0      1  05-Feb-10    1643690.90             0        42.31       2.572
# 1      1  12-Feb-10    1641957.44             1        38.51       2.548
# 2      1  19-Feb-10    1611968.17             0        39.93       2.514
# 3      1  26-Feb-10    1409727.59             0        46.63       2.561
# 4      1  05-Mar-10    1554806.68             0        46.50       2.625
#
#           cpi  unemployment  year  month  day    strdate  dummy_date
# 0  211.096358         8.106  2010      2    5 2010-02-05           1
# 1  211.242170         8.106  2010      2   12 2010-02-12           2
# 2  211.289143         8.106  2010      2   19 2010-02-19           3
# 3  211.319643         8.106  2010      2   26 2010-02-26           4
# 4  211.350143         8.106  2010      3    5 2010-03-05           5

# %%
model_dataset = store1_dataset[['store','holiday_flag','temperature','fuel_price','cpi','unemployment','year','month','day','dummy_date','weekly_sales']]

model_dataset.head()
# Out:
#    store  holiday_flag  temperature  fuel_price         cpi  unemployment  \
# 0      1             0        42.31       2.572  211.096358         8.106
# 1      1             1        38.51       2.548  211.242170         8.106
# 2      1             0        39.93       2.514  211.289143         8.106
# 3      1             0        46.63       2.561  211.319643         8.106
# 4      1             0        46.50       2.625  211.350143         8.106
#
#    year  month  day  dummy_date  weekly_sales
# 0  2010      2    5           1    1643690.90
# 1  2010      2   12           2    1641957.44
# 2  2010      2   19           3    1611968.17
# 3  2010      2   26           4    1409727.59
# 4  2010      3    5           5    1554806.68

# %%
#splitting data into train and test for the linear model

train,test = train_test_split(model_dataset, test_size=0.20, random_state=0)
lr = LinearRegression()

x_train = train.drop(columns=['weekly_sales'])
x_test = test.drop(columns=['weekly_sales'])
y_train = train['weekly_sales']
y_test = test['weekly_sales']

# %%
#fitting the model

lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#finding the beta() value

lr.intercept_
# Out:
# -2364627031.701775

# %%
-2364627031.7017293
#predicting the weekly sales using the test data

y_pred = lr.predict(x_test)
y_pred.shape, y_test.shape
# Out:
# ((29,), (29,))

# %%
#finding R2 score

print("Test Score = {:.2f}".format(metrics.r2_score(y_test, y_pred)))
Test Score = 0.36
print("Train Score = {:.2f}".format(lr.score(x_train, y_train)))
# Out:
# Test Score = 0.36

# %%
print("Train Score = {:.2f}".format(lr.score(x_train, y_train)))
# Out:
# Train Score = 0.24

# %%
#performing ordinary least square method

fts = '+'.join(train.drop(columns=['weekly_sales']).columns)
linear_model = ols('weekly_sales~'+fts, data=train).fit()
linear_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           weekly_sales   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                  0.171
# Method:                 Least Squares   F-statistic:                     3.585
# Date:                Tue, 28 Feb 2023   Prob (F-statistic):           0.000644
# Time:                        14:28:53   Log-Likelihood:                -1506.8
# No. Observations:                 114   AIC:                             3034.
# Df Residuals:                     104   BIC:                             3061.
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept    -1.182e+09   1.02e+10     -0.116      0.908   -2.14e+10     1.9e+10
# store        -1.182e+09   1.02e+10     -0.116      0.908   -2.14e+10     1.9e+10
# holiday_flag  5.748e+04   5.19e+04      1.107      0.271   -4.55e+04     1.6e+05
# temperature  -2791.4208   1171.719     -2.382      0.019   -5114.984    -467.857
# fuel_price    4.154e+04   7.15e+04      0.581      0.562      -1e+05    1.83e+05
# cpi           2.514e+04   1.46e+04      1.717      0.089   -3892.399    5.42e+04
# unemployment  1.591e+04   6.82e+04      0.233      0.816   -1.19e+05    1.51e+05
# year          1.174e+06   1.01e+07      0.116      0.908   -1.89e+07    2.13e+07
# month         1.114e+05   8.44e+05      0.132      0.895   -1.56e+06    1.78e+06
# day          -1522.8776   2.77e+04     -0.055      0.956   -5.65e+04    5.34e+04
# dummy_date   -2.452e+04   1.94e+05     -0.127      0.900   -4.09e+05     3.6e+05
# ==============================================================================
# Omnibus:                      107.827   Durbin-Watson:                   2.041
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1379.530
# Skew:                           3.169   Prob(JB):                    2.75e-300
# Kurtosis:                      18.819   Cond. No.                     5.23e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.71e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\asus\appdata\roaming\python\python310\site-packages (0.12.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\asus\appdata\roaming\python\python310\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\asus\appdata\roaming\python\python310\site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\asus\appdata\roaming\python\python310\site-packages (from seaborn) (3.7.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\asus\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\roaming\python\python310\site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# [notice] A new release of pip available: 22.2.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Fuel Price vs. Weekly Sales

plt.figure(figsize=(15,15))
sns.set(font_scale=1.2, style="white")
sns.lmplot(x='fuel_price', y='weekly_sales', data=store1_dataset, line_kws={'color':'red'})
plt.title("Fuel Price vs. Weekly Sales")
plt.xlabel("Fuel Price")
plt.ylabel("Weekly Sales")
plt.show()

# %%
#CPI vs. Weekly Sales

plt.figure(figsize=(15,15))
sns.set(font_scale=1.2, style="white")
sns.lmplot(x='cpi', y='weekly_sales', data=store1_dataset, line_kws={'color':'red'})
plt.title("CPI vs. Weekly Sales")
plt.xlabel("CPI")
plt.ylabel("Weekly Sales")
plt.show()

# %%
#Unemployment vs. Weekly Sales

plt.figure(figsize=(15,15))
sns.set(font_scale=1.2, style="white")
sns.lmplot(x='unemployment', y='weekly_sales', data=store1_dataset, line_kws={'color':'red'})
plt.title("Unemployment vs. Weekly Sales")
plt.xlabel("Unemployment")
plt.ylabel("Weekly Sales")
plt.show()

# %%
#converting string object to datetime object

dataframe['date'] = pd.to_datetime(dataframe['date'])

# %%
#changing dates to the day of the week

dataframe['day of week'] = dataframe['date'].dt.day_name()
dataframe.head()
# Out:
#    store       date  weekly_sales  holiday_flag  temperature  fuel_price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
#
#           cpi  unemployment  year month  day day of week
# 0  211.096358         8.106  2010   Feb    5      Friday
# 1  211.242170         8.106  2010   Feb   12      Friday
# 2  211.289143         8.106  2010   Feb   19      Friday
# 3  211.319643         8.106  2010   Feb   26      Friday
# 4  211.350143         8.106  2010   Mar    5      Friday
